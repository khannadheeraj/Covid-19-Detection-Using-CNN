# %% [markdown]
# ## Create Data For Positive Sample

# %%
import pandas as pd
import os
import shutil

# %%
FILE_PATH='chest_xray/metadata.csv'
IMAGE_PATH='chest_xray/images'
df=pd.read_csv(FILE_PATH)

# %%
df.shape
# Out:
# (354, 28)

# %%
df.head()
# Out:
#    patientid  offset sex   age   finding survival intubated  \
# 0          2     0.0   M  65.0  COVID-19        Y       NaN
# 1          2     3.0   M  65.0  COVID-19        Y       NaN
# 2          2     5.0   M  65.0  COVID-19        Y       NaN
# 3          2     6.0   M  65.0  COVID-19        Y       NaN
# 4          4     0.0   F  52.0  COVID-19      NaN       NaN
#
#   intubation_present went_icu needed_supplemental_O2  ...              date  \
# 0                NaN      NaN                    NaN  ...  January 22, 2020
# 1                NaN      NaN                    NaN  ...  January 25, 2020
# 2                NaN      NaN                    NaN  ...  January 27, 2020
# 3                NaN      NaN                    NaN  ...  January 28, 2020
# 4                NaN      NaN                    NaN  ...  January 25, 2020
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 2        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 3        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 4  Changhua Christian Hospital, Changhua City, Ta...  images
#
#                                             filename                   doi  \
# 0  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 1  auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 2  auntminnie-c-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 3  auntminnie-d-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 4                              nejmc2001573_f1a.jpeg  10.1056/NEJMc2001573
#
#                                                  url license  \
# 0  https://www.nejm.org/doi/full/10.1056/NEJMc200...     NaN
# 1  https://www.nejm.org/doi/full/10.1056/NEJMc200...     NaN
# 2  https://www.nejm.org/doi/full/10.1056/NEJMc200...     NaN
# 3  https://www.nejm.org/doi/full/10.1056/NEJMc200...     NaN
# 4  https://www.nejm.org/doi/full/10.1056/NEJMc200...     NaN
#
#                                      clinical_notes other_notes Unnamed: 27
# 0     infiltrate in the upper lobe of the left lung         NaN         NaN
# 1          progressive infiltrate and consolidation         NaN         NaN
# 2          progressive infiltrate and consolidation         NaN         NaN
# 3          progressive infiltrate and consolidation         NaN         NaN
# 4  diffuse infiltrates in the bilateral lower lungs         NaN         NaN
#
# [5 rows x 28 columns]

# %%
TARGET_DIR='CovidImage/Covid'
if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("File Created")
# Out:
# File Created

# %% [markdown]
# ## Check How Many Covid Images we Have

# %%
count=0

for (i,row) in df.iterrows():
    if row['finding']=='COVID-19':
        count +=1
print("Total No. Of Covid Image Present is",count)
# Out:
# Total No. Of Covid Image Present is 278

# %% [markdown]
# ## We dont Need The Xray Which Have Top View We Just Need Front View X-ray

# %%
count=0

for (i,row) in df.iterrows():
    if row['finding']=='COVID-19' and row['view']=="PA":
        filename=row['filename']
        image_path=os.path.join(IMAGE_PATH,filename)
        image_copy_path=os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        count +=1
        print("No. Of Images Moved is ",count)
print("Total No. Of Covid Image Present Having PA View",count)
# Out:
# No. Of Images Moved is  1
# No. Of Images Moved is  2
# No. Of Images Moved is  3
# No. Of Images Moved is  4
# No. Of Images Moved is  5
# No. Of Images Moved is  6
# No. Of Images Moved is  7
# No. Of Images Moved is  8
# No. Of Images Moved is  9
# No. Of Images Moved is  10
# No. Of Images Moved is  11
# No. Of Images Moved is  12
# No. Of Images Moved is  13
# No. Of Images Moved is  14
# No. Of Images Moved is  15
# No. Of Images Moved is  16
# No. Of Images Moved is  17
# No. Of Images Moved is  18
# No. Of Images Moved is  19
# No. Of Images Moved is  139
# No. Of Images Moved is  140
# No. Of Images Moved is  141
# No. Of Images Moved is  142
# Total No. Of Covid Image Present Having PA View 142

# %% [markdown]
# ## Now We Will Create Normal Image which we will Extract from Kaggle Dataset

# %%
import random
KAGGLE_IMAGE='chest_xray_kaggle/train/NORMAL'
TARGET_NORMAL_DIR='CovidImage/Normal'

# %%
random.seed(42)

image_names=os.listdir(KAGGLE_IMAGE) ## Give Me List Of All the name of Kaggle Image which is present in Normal Directory

# %%
random.shuffle(images_names)

# %%
for i in range(142):
    image_name=image_names[i]
    image_path=os.path.join(KAGGLE_IMAGE,image_name)
    target_path=os.path.join(TARGET_NORMAL_DIR,image_name)
    shutil.copy2(image_path,target_path)
    print("Copying Image ",i)
# Out:
# Copying Image  0
# Copying Image  1
# Copying Image  2
# Copying Image  3
# Copying Image  4
# Copying Image  5
# Copying Image  6
# Copying Image  7
# Copying Image  8
# Copying Image  9
# Copying Image  10
# Copying Image  11
# Copying Image  12
# Copying Image  13
# Copying Image  14
# Copying Image  15
# Copying Image  16
# Copying Image  17
# Copying Image  18
# Copying Image  19
# Copying Image  20
# Copying Image  21
# Copying Image  22
# Copying Image  23
# Copying Image  24
# Copying Image  25
# Copying Image  26
# Copying Image  27
# Copying Image  28
# Copying Image  29
# Copying Image  30
# Copying Image  31
# Copying Image  32
# Copying Image  33
# Copying Image  34
# Copying Image  35
# Copying Image  36
# Copying Image  37
# Copying Image  38
# Copying Image  39
# Copying Image  40
# Copying Image  41
# Copying Image  42
# Copying Image  43
# Copying Image  44
# Copying Image  45
# Copying Image  46
# Copying Image  47
# Copying Image  48
# Copying Image  49
# Copying Image  50
# Copying Image  51
# Copying Image  52
# Copying Image  53
# Copying Image  54
# Copying Image  55
# Copying Image  56
# Copying Image  57
# Copying Image  58
# Copying Image  59
# Copying Image  60
# Copying Image  61
# Copying Image  62
# Copying Image  63
# Copying Image  64
# Copying Image  65
# Copying Image  66
# Copying Image  67
# Copying Image  68
# Copying Image  69
# Copying Image  70
# Copying Image  71
# Copying Image  72
# Copying Image  73
# Copying Image  74
# Copying Image  75
# Copying Image  76
# Copying Image  77
# Copying Image  78
# Copying Image  79
# Copying Image  80
# Copying Image  81
# Copying Image  82
# Copying Image  83
# Copying Image  84
# Copying Image  85
# Copying Image  86
# Copying Image  87
# Copying Image  88
# Copying Image  89
# Copying Image  90
# Copying Image  91
# Copying Image  92
# Copying Image  93
# Copying Image  94
# Copying Image  95
# Copying Image  96
# Copying Image  97
# Copying Image  98
# Copying Image  99
# Copying Image  100
# Copying Image  101
# Copying Image  102
# Copying Image  103
# Copying Image  104
# Copying Image  105
# Copying Image  106
# Copying Image  107
# Copying Image  108
# Copying Image  109
# Copying Image  110
# Copying Image  111
# Copying Image  112
# Copying Image  113
# Copying Image  114
# Copying Image  115
# Copying Image  116
# Copying Image  117
# Copying Image  118
# Copying Image  119
# Copying Image  120
# Copying Image  121
# Copying Image  122
# Copying Image  123
# Copying Image  124
# Copying Image  125
# Copying Image  126
# Copying Image  127
# Copying Image  128
# Copying Image  129
# Copying Image  130
# Copying Image  131
# Copying Image  132
# Copying Image  133
# Copying Image  134
# Copying Image  135
# Copying Image  136
# Copying Image  137
# Copying Image  138
# Copying Image  139
# Copying Image  140
# Copying Image  141
